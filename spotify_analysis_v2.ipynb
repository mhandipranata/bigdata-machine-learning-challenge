# %% [markdown]
# # Spotify Data Cleaning and Analysis

# %% [markdown]
# ### Genres:
# - Pop
# - Hip-hop
# - Jazz
# - Rock
# - K-pop
# - Instrumental
# - ASMR

# %% [markdown]
# ### Features Definitions:
#
# - Danceability - The higher the value, the easier it is to dance to this song. Danceability describes how suitable a track is for dancing based on a combination of muical elements including tempo, rhythm stability, beat strength, and overall regurality.
# - Energy - the higher the value, the more energtic the song is. Energy represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
# - Acousticness - The higher the value the more acoustic the song is.
# - Instrumentalness - The higher the value the greater likelihood the track contains no vocal content. Instrumentalness predicts whether a track contains no vocals.
# - Valence - The higher the value, the more positive mood for the song. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# - Speechiness - The higher the value the more spoken word the song contains.
# - Loudness (dB) - The higher the value, the louder the song. Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Values typical range between -60 and 0 dB.
# - Tempo (BPM) - The tempo of the song (beats per minute).
# - Popularity - The higher the value the more popular the song is.

# %%
import pandas as pd

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# ## Extract The Necessary Columns

# %% [markdown]
# ### Pop

# %%
# Read the spotify csv data for each genres
pop = pd.read_csv("spotify_data_pop_v2.csv")
pop.head()
# Out:
#       artist_name       track_name  popularity                track_id  \
# 0      The Weeknd  Blinding Lights         100  0VjIjW4GlUZAMYd2vXMi3b
# 1        Dua Lipa  Don't Start Now          97  6WrI0LAC5M1Rw2MnX2ZvEg
# 2        Doja Cat           Say So          97  3Dv1eDb0MEgF93GpLXlucZ
# 3  Arizona Zervas          ROXANNE          95  696DnlkuDOXcMAnKlTgXXK
# 4           BENEE       Supalonely          95  4nK5YrxbMGZstTLbvj6Gxw
#
#                               track_uri  danceability  energy  loudness  \
# 0  spotify:track:0VjIjW4GlUZAMYd2vXMi3b         0.514   0.730    -5.934
# 1  spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg         0.794   0.793    -4.521
# 2  spotify:track:3Dv1eDb0MEgF93GpLXlucZ         0.787   0.673    -4.577
# 3  spotify:track:696DnlkuDOXcMAnKlTgXXK         0.621   0.601    -5.616
# 4  spotify:track:4nK5YrxbMGZstTLbvj6Gxw         0.863   0.631    -4.689
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0598       0.00146          0.000095    0.0897    0.334  171.005
# 1       0.0842       0.01250          0.000000    0.0952    0.677  123.941
# 2       0.1580       0.25600          0.000004    0.0904    0.786  110.962
# 3       0.1480       0.05220          0.000000    0.4600    0.457  116.735
# 4       0.0534       0.30500          0.000030    0.1230    0.817  128.977
#
#    duration genre
# 0    200040   pop
# 1    183290   pop
# 2    237893   pop
# 3    163636   pop
# 4    223480   pop

# %%
pop_clean = pop[[
    'genre', 'danceability', 'energy', 'acousticness', 'instrumentalness', 
    'valence', 'speechiness', 'loudness','tempo'
]]
pop_clean.dropna(inplace=True)
pop_clean.head()
# Out:
# /Users/michellehandipranata/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   genre  danceability  energy  acousticness  instrumentalness  valence  \
# 0   pop         0.514   0.730       0.00146          0.000095    0.334
# 1   pop         0.794   0.793       0.01250          0.000000    0.677
# 2   pop         0.787   0.673       0.25600          0.000004    0.786
# 3   pop         0.621   0.601       0.05220          0.000000    0.457
# 4   pop         0.863   0.631       0.30500          0.000030    0.817
#
#    speechiness  loudness    tempo
# 0       0.0598    -5.934  171.005
# 1       0.0842    -4.521  123.941
# 2       0.1580    -4.577  110.962
# 3       0.1480    -5.616  116.735
# 4       0.0534    -4.689  128.977

# %% [markdown]
# ### Hip-hop

# %%
# Read the spotify csv data for each genres
hiphop = pd.read_csv("spotify_data_hiphop_v2.csv")
hiphop.head()
# Out:
#    artist_name                        track_name  popularity  \
# 0        Drake                      Toosie Slide          99
# 1  Jack Harlow                      WHATS POPPIN          93
# 2       Future        Life Is Good (feat. Drake)          94
# 3       DaBaby      ROCKSTAR (feat. Roddy Ricch)          91
# 4   NLE Choppa  Walk Em Down (feat. Roddy Ricch)          90
#
#                  track_id                             track_uri  danceability  \
# 0  127QTOFJsJQp5LbJbu3A1y  spotify:track:127QTOFJsJQp5LbJbu3A1y         0.834
# 1  1jaTQ3nqY3oAAYyCTbIvnM  spotify:track:1jaTQ3nqY3oAAYyCTbIvnM         0.923
# 2  5yY9lUy8nbvjM1Uyo1Uqoc  spotify:track:5yY9lUy8nbvjM1Uyo1Uqoc         0.676
# 3  7ytR5pFWmSjzHJIeQkgog4  spotify:track:7ytR5pFWmSjzHJIeQkgog4         0.746
# 4  4cSSL3YafYjM3yjgFO1vJg  spotify:track:4cSSL3YafYjM3yjgFO1vJg         0.867
#
#    energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.454    -9.750        0.201        0.3210          0.000006    0.1140
# 1   0.604    -6.671        0.245        0.0170          0.000000    0.2720
# 2   0.609    -5.831        0.481        0.0706          0.000000    0.1520
# 3   0.690    -7.956        0.164        0.2470          0.000000    0.1010
# 4   0.744    -5.171        0.228        0.2680          0.000000    0.0713
#
#    valence    tempo  duration   genre
# 0    0.837   81.618    247059  hiphop
# 1    0.826  145.062    139741  hiphop
# 2    0.508  142.037    237735  hiphop
# 3    0.497   89.977    181733  hiphop
# 4    0.645   84.005    173288  hiphop

# %%
hiphop_clean = hiphop[[
    'genre', 'danceability', 'energy', 'acousticness', 'instrumentalness', 
    'valence', 'speechiness', 'loudness','tempo'
]]
hiphop_clean.dropna(inplace=True)
hiphop_clean.head()
# Out:
# /Users/michellehandipranata/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#     genre  danceability  energy  acousticness  instrumentalness  valence  \
# 0  hiphop         0.834   0.454        0.3210          0.000006    0.837
# 1  hiphop         0.923   0.604        0.0170          0.000000    0.826
# 2  hiphop         0.676   0.609        0.0706          0.000000    0.508
# 3  hiphop         0.746   0.690        0.2470          0.000000    0.497
# 4  hiphop         0.867   0.744        0.2680          0.000000    0.645
#
#    speechiness  loudness    tempo
# 0        0.201    -9.750   81.618
# 1        0.245    -6.671  145.062
# 2        0.481    -5.831  142.037
# 3        0.164    -7.956   89.977
# 4        0.228    -5.171   84.005

# %% [markdown]
# ### Jazz

# %%
# Read the spotify csv data for each genres
jazz = pd.read_csv("spotify_data_jazz_v2.csv")
jazz['genre'] = 'jazz'
jazz.head()
# Out:
#               artist_name                               track_name  \
# 0      Earth, Wind & Fire                                September
# 1         Louis Armstrong  What A Wonderful World - Single Version
# 2         Leslie Odom Jr.                       Alexander Hamilton
# 3              Etta James                                  At Last
# 4  Grover Washington, Jr.  Just the Two of Us (feat. Bill Withers)
#
#    popularity                track_id                             track_uri  \
# 0          82  7Cuk8jsPPoNYQWXK9XRFvG  spotify:track:7Cuk8jsPPoNYQWXK9XRFvG
# 1          68  29U7stRjqHU6rMiS8BfaI9  spotify:track:29U7stRjqHU6rMiS8BfaI9
# 2          71  4TTV7EcfroSLWzXRY6gLv6  spotify:track:4TTV7EcfroSLWzXRY6gLv6
# 3          75  4Hhv2vrOTy89HFRcjU3QOx  spotify:track:4Hhv2vrOTy89HFRcjU3QOx
# 4          71  1ko2lVN0vKGUl9zrU0qSlT  spotify:track:1ko2lVN0vKGUl9zrU0qSlT
#
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.694   0.831    -7.288       0.0301         0.165
# 1         0.271   0.165   -20.652       0.0351         0.729
# 2         0.609   0.435    -7.862       0.2840         0.524
# 3         0.273   0.347    -8.631       0.0292         0.546
# 4         0.803   0.488    -9.303       0.0803         0.576
#
#    instrumentalness  liveness  valence    tempo  duration genre
# 0          0.000892    0.2500    0.980  125.901    215080  jazz
# 1          0.000002    0.1180    0.203   77.082    139227  jazz
# 2          0.000000    0.1180    0.563  131.998    236738  jazz
# 3          0.013700    0.3340    0.328   87.411    179693  jazz
# 4          0.060900    0.0763    0.624   95.771    237106  jazz

# %%
jazz_clean = jazz[[
    'genre', 'danceability', 'energy', 'acousticness', 'instrumentalness', 
    'valence', 'speechiness', 'loudness','tempo'
]]
jazz_clean.dropna(inplace=True)
jazz_clean.head()
# Out:
# /Users/michellehandipranata/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   genre  danceability  energy  acousticness  instrumentalness  valence  \
# 0  jazz         0.694   0.831         0.165          0.000892    0.980
# 1  jazz         0.271   0.165         0.729          0.000002    0.203
# 2  jazz         0.609   0.435         0.524          0.000000    0.563
# 3  jazz         0.273   0.347         0.546          0.013700    0.328
# 4  jazz         0.803   0.488         0.576          0.060900    0.624
#
#    speechiness  loudness    tempo
# 0       0.0301    -7.288  125.901
# 1       0.0351   -20.652   77.082
# 2       0.2840    -7.862  131.998
# 3       0.0292    -8.631   87.411
# 4       0.0803    -9.303   95.771

# %% [markdown]
# ### Rock

# %%
# Read the spotify csv data for each genres
rock = pd.read_csv("spotify_data_rock_v2.csv")
rock['genre'] = 'rock'
rock.head()
# Out:
#          artist_name                         track_name  popularity  \
# 0  Twenty One Pilots                   Level of Concern          88
# 1            Wallows  Are You Bored Yet? (feat. Clairo)          81
# 2          Grouplove                        Tongue Tied          81
# 3    Imagine Dragons                           Believer          88
# 4        The Killers                     Mr. Brightside          78
#
#                  track_id                             track_uri  danceability  \
# 0  6xZ4Q2k2ompmDppyeESIY8  spotify:track:6xZ4Q2k2ompmDppyeESIY8         0.754
# 1  57RA3JGafJm5zRtKJiKPIm  spotify:track:57RA3JGafJm5zRtKJiKPIm         0.682
# 2  0GO8y8jQk1PkHzS31d699N  spotify:track:0GO8y8jQk1PkHzS31d699N         0.560
# 3  0pqnGHJpmpxLKifKRmU6WP  spotify:track:0pqnGHJpmpxLKifKRmU6WP         0.776
# 4  7oK9VyNzrYvRFo7nQEYkWN  spotify:track:7oK9VyNzrYvRFo7nQEYkWN         0.356
#
#    energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.583    -7.340       0.0432       0.32000          0.000150    0.1440
# 1   0.683    -6.444       0.0287       0.15600          0.000023    0.2730
# 2   0.936    -5.835       0.0439       0.00847          0.000000    0.1610
# 3   0.780    -4.374       0.1280       0.06220          0.000000    0.0810
# 4   0.924    -3.740       0.0808       0.00101          0.000000    0.0953
#
#    valence    tempo  duration genre
# 0    0.770  122.012    220051  rock
# 1    0.640  120.023    178000  rock
# 2    0.371  112.960    218013  rock
# 3    0.666  124.949    204347  rock
# 4    0.232  148.017    222587  rock

# %%
rock_clean = rock[[
    'genre', 'danceability', 'energy', 'acousticness', 'instrumentalness', 
    'valence', 'speechiness', 'loudness','tempo'
]]
rock_clean.dropna(inplace=True)
rock_clean.head()
# Out:
# /Users/michellehandipranata/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   genre  danceability  energy  acousticness  instrumentalness  valence  \
# 0  rock         0.754   0.583       0.32000          0.000150    0.770
# 1  rock         0.682   0.683       0.15600          0.000023    0.640
# 2  rock         0.560   0.936       0.00847          0.000000    0.371
# 3  rock         0.776   0.780       0.06220          0.000000    0.666
# 4  rock         0.356   0.924       0.00101          0.000000    0.232
#
#    speechiness  loudness    tempo
# 0       0.0432    -7.340  122.012
# 1       0.0287    -6.444  120.023
# 2       0.0439    -5.835  112.960
# 3       0.1280    -4.374  124.949
# 4       0.0808    -3.740  148.017

# %% [markdown]
# ### K-pop

# %%
# Read the spotify csv data for each genres
kpop = pd.read_csv("spotify_data_kpop_v2.csv")
kpop['genre'] = 'kpop'
kpop.head()
# Out:
#   artist_name                   track_name  popularity  \
# 0         BTS                           ON          85
# 1         BTS  Boy With Luv (feat. Halsey)          84
# 2         BTS                       Filter          82
# 3         BTS                      My Time          81
# 4         BTS               ON (Feat. Sia)          81
#
#                  track_id                             track_uri  danceability  \
# 0  2QyuXBcV1LJ2rq01KhreMF  spotify:track:2QyuXBcV1LJ2rq01KhreMF         0.583
# 1  5KawlOMHjWeUjQtnuRs22c  spotify:track:5KawlOMHjWeUjQtnuRs22c         0.645
# 2  0ono6UCNVZ1XqOm6j78Blu  spotify:track:0ono6UCNVZ1XqOm6j78Blu         0.781
# 3  4vTgx6h4seHvkuFh84JXYP  spotify:track:4vTgx6h4seHvkuFh84JXYP         0.674
# 4  3IB5qOeMayvpOdHxYCL5tZ  spotify:track:3IB5qOeMayvpOdHxYCL5tZ         0.591
#
#    energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.817    -5.146       0.0987        0.1180               0.0    0.3380
# 1   0.862    -4.757       0.0965        0.0923               0.0    0.1920
# 2   0.762    -5.188       0.0626        0.0222               0.0    0.1210
# 3   0.640    -5.139       0.0339        0.1510               0.0    0.0925
# 4   0.848    -4.397       0.0828        0.1370               0.0    0.3720
#
#    valence    tempo  duration genre
# 0    0.438  105.936    246381  kpop
# 1    0.798  119.991    229773  kpop
# 2    0.860  110.042    180221  kpop
# 3    0.664   99.908    234458  kpop
# 4    0.386  105.922    246816  kpop

# %%
kpop_clean = kpop[[
    'genre', 'danceability', 'energy', 'acousticness', 'instrumentalness', 
    'valence', 'speechiness', 'loudness','tempo'
]]
kpop_clean.dropna(inplace=True)
kpop_clean.head()
# Out:
# /Users/michellehandipranata/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   genre  danceability  energy  acousticness  instrumentalness  valence  \
# 0  kpop         0.583   0.817        0.1180               0.0    0.438
# 1  kpop         0.645   0.862        0.0923               0.0    0.798
# 2  kpop         0.781   0.762        0.0222               0.0    0.860
# 3  kpop         0.674   0.640        0.1510               0.0    0.664
# 4  kpop         0.591   0.848        0.1370               0.0    0.386
#
#    speechiness  loudness    tempo
# 0       0.0987    -5.146  105.936
# 1       0.0965    -4.757  119.991
# 2       0.0626    -5.188  110.042
# 3       0.0339    -5.139   99.908
# 4       0.0828    -4.397  105.922

# %% [markdown]
# ### Instrumental

# %%
# Read the spotify csv data for each genres
instrumental = pd.read_csv("spotify_data_instrumental_v2.csv")
instrumental.head()
# Out:
#       artist_name               track_name  popularity  \
# 0   Steve Mokwebe          It Ends with Us          68
# 1  Rannar Sillard            Dream Voucher          68
# 2      Vala Capon  Presto arriverà il sole          69
# 3         Benette            Lily's Cradle          68
# 4    Ever So Blue                  Cessura          70
#
#                  track_id                             track_uri  danceability  \
# 0  6RMjZgsE9IcQZqubTzLtDs  spotify:track:6RMjZgsE9IcQZqubTzLtDs         0.326
# 1  2T6wyxLBkQ4Y2ZjTbpuYfr  spotify:track:2T6wyxLBkQ4Y2ZjTbpuYfr         0.302
# 2  2jyJXuG0rIma11mOl4Fz7m  spotify:track:2jyJXuG0rIma11mOl4Fz7m         0.378
# 3  4UlarjdicLUPbdssOxWbYX  spotify:track:4UlarjdicLUPbdssOxWbYX         0.368
# 4  7uvey8m0ZfknE25sBVWoGY  spotify:track:7uvey8m0ZfknE25sBVWoGY         0.374
#
#     energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0  0.00891   -24.103       0.0518         0.986             0.934    0.1110
# 1  0.10100   -19.705       0.0378         0.943             0.886    0.1070
# 2  0.04370   -26.159       0.0357         0.995             0.920    0.0983
# 3  0.00892   -29.555       0.0500         0.990             0.911    0.1020
# 4  0.09890   -28.377       0.0326         0.991             0.805    0.0799
#
#    valence    tempo  duration         genre
# 0    0.299   69.790    130192  instrumental
# 1    0.213  106.904    155040  instrumental
# 2    0.423   77.211    152000  instrumental
# 3    0.287   63.639    161267  instrumental
# 4    0.342  152.840    185390  instrumental

# %%
instrumental_clean = instrumental[[
    'genre', 'danceability', 'energy', 'acousticness', 'instrumentalness', 
    'valence', 'speechiness', 'loudness','tempo'
]]
instrumental_clean.dropna(inplace=True)
instrumental_clean.head()
# Out:
# /Users/michellehandipranata/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#           genre  danceability   energy  acousticness  instrumentalness  \
# 0  instrumental         0.326  0.00891         0.986             0.934
# 1  instrumental         0.302  0.10100         0.943             0.886
# 2  instrumental         0.378  0.04370         0.995             0.920
# 3  instrumental         0.368  0.00892         0.990             0.911
# 4  instrumental         0.374  0.09890         0.991             0.805
#
#    valence  speechiness  loudness    tempo
# 0    0.299       0.0518   -24.103   69.790
# 1    0.213       0.0378   -19.705  106.904
# 2    0.423       0.0357   -26.159   77.211
# 3    0.287       0.0500   -29.555   63.639
# 4    0.342       0.0326   -28.377  152.840

# %% [markdown]
# ### ASMR

# %%
# Read the spotify csv data for each genres
asmr = pd.read_csv("spotify_data_asmr_v2.csv")
asmr.head()
# Out:
#               artist_name           track_name  popularity  \
# 0         Weather Factory    Deep Thunderstorm          74
# 1         Weather Factory  Calm Rain & Thunder          73
# 2         Weather Factory  Forest Thunderstorm          70
# 3  Masters of Binaurality      Gamma Freq Pads          64
# 4       Mindful Behaviour           Alpha 8 Hz          63
#
#                  track_id                             track_uri  danceability  \
# 0  4xyiM6KWF90l9wQh07GJvN  spotify:track:4xyiM6KWF90l9wQh07GJvN         0.135
# 1  5fkUSLLclp3LdXiMw3zTgR  spotify:track:5fkUSLLclp3LdXiMw3zTgR         0.160
# 2  5lyslBBFXOiu2uB0sEdLSa  spotify:track:5lyslBBFXOiu2uB0sEdLSa         0.142
# 3  1yOlQ6v0E3Jgo9iY0dtMyQ  spotify:track:1yOlQ6v0E3Jgo9iY0dtMyQ         0.205
# 4  5VV9fAmGLlXsK568Uax9A2  spotify:track:5VV9fAmGLlXsK568Uax9A2         0.243
#
#    energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0  0.5790   -27.105       0.0932       0.00143             0.949     0.393
# 1  0.5600   -25.388       0.0772       0.00238             0.714     0.413
# 2  0.9100   -20.770       0.1150       0.04690             0.957     0.509
# 3  0.1210   -16.988       0.0489       0.71300             0.939     0.110
# 4  0.0632   -31.781       0.0838       0.99600             0.794     0.106
#
#    valence    tempo  duration genre
# 0   0.0327  100.841    152563  asmr
# 1   0.0271  129.874    200693  asmr
# 2   0.0135   65.291    150444  asmr
# 3   0.0283   71.895    220606  asmr
# 4   0.0531  137.632    224049  asmr

# %%
asmr_clean = asmr[[
    'genre', 'danceability', 'energy', 'acousticness', 'instrumentalness', 
    'valence', 'speechiness', 'loudness', 'tempo'
]]
asmr_clean.dropna(inplace=True)
asmr_clean.head()
# Out:
# /Users/michellehandipranata/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   genre  danceability  energy  acousticness  instrumentalness  valence  \
# 0  asmr         0.135  0.5790       0.00143             0.949   0.0327
# 1  asmr         0.160  0.5600       0.00238             0.714   0.0271
# 2  asmr         0.142  0.9100       0.04690             0.957   0.0135
# 3  asmr         0.205  0.1210       0.71300             0.939   0.0283
# 4  asmr         0.243  0.0632       0.99600             0.794   0.0531
#
#    speechiness  loudness    tempo
# 0       0.0932   -27.105  100.841
# 1       0.0772   -25.388  129.874
# 2       0.1150   -20.770   65.291
# 3       0.0489   -16.988   71.895
# 4       0.0838   -31.781  137.632

# %% [markdown]
# ## Check Value Types and Min Max Values for Each Features

# %%
print("Pop Data Types: ")
print(pop_clean.dtypes)
print("---------------------------------------")

print("Hiphop Data Types: ")
print(hiphop_clean.dtypes)
print("---------------------------------------")

print("Jazz Data Types: ")
print(jazz_clean.dtypes)
print("---------------------------------------")

print("Rock Data Types: ")
print(rock_clean.dtypes)
print("---------------------------------------")

print("Kpop Data Types: ")
print(kpop_clean.dtypes)
print("---------------------------------------")

print("Instrumental Data Types: ")
print(instrumental_clean.dtypes)
print("---------------------------------------")

print("ASMR Data Types: ")
print(asmr_clean.dtypes)
# Out:
# Pop Data Types:
# genre                object
# danceability        float64
# energy              float64
# acousticness        float64
# instrumentalness    float64
# valence             float64
# speechiness         float64
# loudness            float64
# tempo               float64
# dtype: object
# ---------------------------------------
# Hiphop Data Types:
# genre                object
# danceability        float64
# energy              float64
# acousticness        float64
# instrumentalness    float64
# valence             float64
# speechiness         float64
# loudness            float64
# tempo               float64
# dtype: object
# ---------------------------------------
# Jazz Data Types:
# genre                object
# danceability        float64
# energy              float64
# acousticness        float64
# instrumentalness    float64
# valence             float64
# speechiness         float64
# loudness            float64
# tempo               float64
# dtype: object
# ---------------------------------------
# Rock Data Types:
# genre                object
# danceability        float64
# energy              float64
# acousticness        float64
# instrumentalness    float64
# valence             float64
# speechiness         float64
# loudness            float64
# tempo               float64
# dtype: object
# ---------------------------------------
# Kpop Data Types:
# genre                object
# danceability        float64
# energy              float64
# acousticness        float64
# instrumentalness    float64
# valence             float64
# speechiness         float64
# loudness            float64
# tempo               float64
# dtype: object
# ---------------------------------------
# Instrumental Data Types:
# genre                object
# danceability        float64
# energy              float64
# acousticness        float64
# instrumentalness    float64
# valence             float64
# speechiness         float64
# loudness            float64
# tempo               float64
# dtype: object
# ---------------------------------------
# ASMR Data Types:
# genre                object
# danceability        float64
# energy              float64
# acousticness        float64
# instrumentalness    float64
# valence             float64
# speechiness         float64
# loudness            float64
# tempo               float64
# dtype: object

# %%
print("Pop")
pop_clean.describe()
# Out:
# Pop
#        danceability       energy  acousticness  instrumentalness      valence  \
# count   1000.000000  1000.000000   1000.000000       1000.000000  1000.000000
# mean       0.679188     0.589186      0.243901          0.003028     0.481089
# std        0.136654     0.148100      0.262278          0.018200     0.231616
# min        0.378000     0.267000      0.001460          0.000000     0.059200
# 25%        0.572000     0.483000      0.023700          0.000000     0.284000
# 50%        0.676000     0.580000      0.127000          0.000000     0.480000
# 75%        0.806000     0.700000      0.449000          0.000012     0.680000
# max        0.923000     0.955000      0.946000          0.130000     0.952000
#
#        speechiness     loudness        tempo
# count  1000.000000  1000.000000  1000.000000
# mean      0.096540    -6.229181   119.265083
# std       0.098924     1.816456    24.239718
# min       0.025900   -10.965000    75.025000
# 25%       0.042225    -7.206000   102.819000
# 50%       0.057500    -6.027000   113.039000
# 75%       0.092400    -4.858000   139.980000
# max       0.481000    -3.046000   171.649000

# %%
print("Hiphop")
hiphop_clean.describe()
# Out:
# Hiphop
#        danceability       energy  acousticness  instrumentalness      valence  \
# count   1000.000000  1000.000000   1000.000000       1000.000000  1000.000000
# mean       0.793107     0.559354      0.203739          0.001012     0.491629
# std        0.117259     0.110177      0.212072          0.003319     0.200612
# min        0.453000     0.304000      0.000282          0.000000     0.100000
# 25%        0.734000     0.486000      0.062200          0.000000     0.345000
# 50%        0.810000     0.559000      0.111000          0.000000     0.460000
# 75%        0.889000     0.624000      0.259000          0.000021     0.620000
# max        0.970000     0.847000      0.874000          0.018400     0.966000
#
#        speechiness     loudness        tempo
# count  1000.000000  1000.000000  1000.000000
# mean      0.204672    -7.099988   121.264661
# std       0.130120     2.080736    26.550106
# min       0.028600   -11.713000    75.023000
# 25%       0.092400    -8.465000   100.000000
# 50%       0.164000    -6.972000   122.973000
# 75%       0.332000    -5.723000   142.069000
# max       0.530000    -2.708000   175.041000

# %%
print("Jazz")
jazz_clean.describe()
# Out:
# Jazz
#        danceability       energy  acousticness  instrumentalness      valence  \
# count   1000.000000  1000.000000   1000.000000       1000.000000  1000.000000
# mean       0.525875     0.281834      0.726441          0.087477     0.423316
# std        0.150688     0.232828      0.261203          0.235424     0.218146
# min        0.172000     0.007560      0.068200          0.000000     0.054100
# 25%        0.420000     0.104000      0.596000          0.000001     0.230000
# 50%        0.517000     0.199000      0.833000          0.000699     0.375000
# 75%        0.622250     0.398000      0.923000          0.009150     0.613000
# max        0.848000     0.924000      0.993000          0.948000     0.980000
#
#        speechiness     loudness        tempo
# count  1000.000000  1000.000000  1000.000000
# mean      0.078755   -14.063774   111.913961
# std       0.112398     5.727891    34.116181
# min       0.024700   -27.331000    49.689000
# 25%       0.032700   -18.749000    86.130000
# 50%       0.038600   -13.193000   108.229000
# 75%       0.053800    -9.767000   131.755750
# max       0.648000    -4.729000   206.247000

# %%
print("Rock")
rock_clean.describe()
# Out:
# Rock
#        danceability       energy  acousticness  instrumentalness      valence  \
# count   1000.000000  1000.000000   1000.000000       1000.000000  1000.000000
# mean       0.577392     0.666217      0.168150          0.028510     0.527536
# std        0.119430     0.182031      0.185707          0.115975     0.203702
# min        0.310000     0.161000      0.000025          0.000000     0.136000
# 25%        0.501000     0.532000      0.018300          0.000000     0.361000
# 50%        0.579000     0.675000      0.093600          0.000105     0.516000
# 75%        0.645000     0.807000      0.217000          0.000879     0.681000
# max        0.852000     0.952000      0.883000          0.910000     0.965000
#
#        speechiness     loudness        tempo
# count  1000.000000  1000.000000  1000.000000
# mean      0.047821    -7.486857   125.547854
# std       0.029647     3.634668    25.604020
# min       0.025300   -22.320000    74.989000
# 25%       0.031100    -9.348000   108.736000
# 50%       0.037400    -7.174000   124.053000
# 75%       0.050700    -5.021000   141.470000
# max       0.168000    -2.729000   188.386000

# %%
print("Kpop")
kpop_clean.describe()
# Out:
# Kpop
#        danceability       energy  acousticness  instrumentalness      valence  \
# count    1000.00000  1000.000000   1000.000000       1000.000000  1000.000000
# mean        0.65805     0.781011      0.083426          0.000067     0.521027
# std         0.10679     0.092695      0.106968          0.000323     0.176487
# min         0.34700     0.470000      0.001160          0.000000     0.141000
# 25%         0.58300     0.717250      0.011400          0.000000     0.389000
# 50%         0.66100     0.798000      0.032350          0.000000     0.519000
# 75%         0.72000     0.853000      0.118000          0.000000     0.648000
# max         0.87400     0.959000      0.445000          0.001880     0.896000
#
#        speechiness     loudness        tempo
# count  1000.000000  1000.000000  1000.000000
# mean      0.096608    -4.343752   123.932605
# std       0.093025     1.492394    24.864153
# min       0.027600    -7.981000    77.501000
# 25%       0.045000    -5.165000   104.995000
# 50%       0.066500    -4.342000   124.998000
# 75%       0.106000    -3.211000   139.987000
# max       0.483000    -1.339000   176.084000

# %%
print("Instrumental")
instrumental_clean.describe()
# Out:
# Instrumental
#        danceability       energy  acousticness  instrumentalness      valence  \
# count   1000.000000  1000.000000   1000.000000       1000.000000  1000.000000
# mean       0.330933     0.051802      0.961124          0.900726     0.233352
# std        0.153895     0.080273      0.083071          0.113269     0.169139
# min        0.079300     0.002750      0.478000          0.002810     0.034700
# 25%        0.215000     0.013100      0.973000          0.892000     0.091100
# 50%        0.332000     0.028200      0.993000          0.922000     0.216000
# 75%        0.426000     0.062100      0.995000          0.949250     0.313000
# max        0.839000     0.585000      0.996000          0.972000     0.912000
#
#        speechiness     loudness        tempo
# count  1000.000000  1000.000000  1000.000000
# mean      0.048943   -26.328453    98.280007
# std       0.020089     5.438604    34.836254
# min       0.032600   -38.480000    60.584000
# 25%       0.037500   -29.699000    69.882000
# 50%       0.041800   -25.859000    85.191000
# 75%       0.052100   -22.649000   118.281000
# max       0.153000    -7.738000   200.615000

# %%
print("ASMR")
asmr_clean.describe()
# Out:
# ASMR
#        danceability       energy  acousticness  instrumentalness      valence  \
# count   1000.000000  1000.000000   1000.000000       1000.000000  1000.000000
# mean       0.272093     0.230373      0.570336          0.655693     0.095609
# std        0.145651     0.318364      0.416652          0.351641     0.120984
# min        0.073300     0.002680      0.000023          0.000000     0.001020
# 25%        0.168000     0.022200      0.025400          0.445750     0.026900
# 50%        0.213000     0.052200      0.795000          0.808000     0.035000
# 75%        0.346000     0.295000      0.957000          0.941000     0.124000
# max        0.654000     0.998000      0.996000          0.997000     0.580000
#
#        speechiness    loudness        tempo
# count  1000.000000  1000.00000  1000.000000
# mean      0.094388   -29.64915   101.393064
# std       0.064020     9.03640    33.766274
# min       0.030600   -50.61800    65.044000
# 25%       0.052700   -37.97800    73.012000
# 50%       0.064200   -30.71100    87.280000
# 75%       0.141000   -21.93050   130.548000
# max       0.393000   -10.53700   176.654000

# %%
print(pop_clean.shape)
print(hiphop_clean.shape)
print(jazz_clean.shape)
print(rock_clean.shape)
print(kpop_clean.shape)
print(instrumental_clean.shape)
print(asmr_clean.shape)
# Out:
# (1000, 9)
# (1000, 9)
# (1000, 9)
# (1000, 9)
# (1000, 9)
# (1000, 9)
# (1000, 9)

# %% [markdown]
# ### Export Clean DataFrame to New CSV files

# %%
# Export the DataFrames to csv files
pop_clean.to_csv("spotify_data_pop_clean.csv", encoding="utf-8", index=False)
hiphop_clean.to_csv("spotify_data_hiphop_clean.csv", encoding="utf-8", index=False)
jazz_clean.to_csv("spotify_data_jazz_clean.csv", encoding="utf-8", index=False)
rock_clean.to_csv("spotify_data_rock_clean.csv", encoding="utf-8", index=False)
kpop_clean.to_csv("spotify_data_kpop_clean.csv", encoding="utf-8", index=False)
instrumental_clean.to_csv("spotify_data_instrumental_clean.csv", encoding="utf-8", index=False)
asmr_clean.to_csv("spotify_data_asmr_clean.csv", encoding="utf-8", index=False)
